# %%
import pandas as pd

# %%
toyata_data = pd.read_csv("data-main/car_sales/toyota_sales_data_no_header.csv")

# %%
toyata_data.head
# Out:
# <bound method NDFrame.head of          1  16  2024-11-18   Tundra  44496.88  0.05  Completed
# 0        2  11  2024-11-08   Tacoma  34824.72   NaN    Pending
# 1        3   5  2024-11-03  Corolla  20275.08   NaN  Completed
# 2        4  20  2024-11-06  Corolla  20068.93   NaN  Completed
# 3        5   1  2024-11-26   Tundra  49811.99  0.03  Completed
# 4        6  14  2024-11-28     RAV4  34346.20  0.03  Completed
# ...    ...  ..         ...      ...       ...   ...        ...
# 4994  4996   1  2024-11-06  Corolla  21484.83  0.05  Completed
# 4995  4997   8  2024-11-11    Camry  26519.24  0.05    Pending
# 4996  4998  18  2024-11-06   Tacoma  30780.39  0.02  Completed
# 4997  4999  10  2024-11-21  Corolla  22654.59   NaN  Completed
# 4998  5000  13  2024-11-21   Tundra  44525.85   NaN  Cancelled
#
# [4999 rows x 7 columns]>

# %%
toyata_data.head()
# Out:
#    1  16  2024-11-18   Tundra  44496.88  0.05  Completed
# 0  2  11  2024-11-08   Tacoma  34824.72   NaN    Pending
# 1  3   5  2024-11-03  Corolla  20275.08   NaN  Completed
# 2  4  20  2024-11-06  Corolla  20068.93   NaN  Completed
# 3  5   1  2024-11-26   Tundra  49811.99  0.03  Completed
# 4  6  14  2024-11-28     RAV4  34346.20  0.03  Completed

# %%
toyata_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   1           4999 non-null   int64
#  1   16          4999 non-null   int64
#  2   2024-11-18  4999 non-null   str
#  3   Tundra      4999 non-null   str
#  4   44496.88    4999 non-null   float64
#  5   0.05        3725 non-null   float64
#  6   Completed   4999 non-null   str
# dtypes: float64(2), int64(2), str(3)
# memory usage: 273.5 KB

# %%
toyata_data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 toyata_data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
toyata_data.shape
# Out:
# (4999, 7)

# %%
toyata_data.columns
# Out:
# Index(['1', '16', '2024-11-18', 'Tundra', '44496.88', '0.05', 'Completed'], dtype='str')

# %%
toyata_data = pd.read_csv("data-main/car_sales/toyota_sales_data.csv")

# %%
toyata_data.columns
# Out:
# Index(['sale_id', 'sale_rep_id', 'sale_date', 'car_model', 'sale_amount',
#        'commission_pct', 'sale_status'],
#       dtype='str')

# %%
toyata_data.columns.to_list()
# Out:
# ['sale_id',
#  'sale_rep_id',
#  'sale_date',
#  'car_model',
#  'sale_amount',
#  'commission_pct',
#  'sale_status']

# %%
toyata_data.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 toyata_data.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
toyata_data.dtypes
# Out:
# sale_id             int64
# sale_rep_id         int64
# sale_date             str
# car_model             str
# sale_amount       float64
# commission_pct    float64
# sale_status           str
# dtype: object

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas:
#
# read_csv(
#     filepath_or_buffer: FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str],
#     *,
#     sep: str | None | lib.NoDefault = <no_default>,
#     delimiter: str | None | lib.NoDefault = None,
#     header: int | Sequence[int] | None | Literal['infer'] = 'infer',
#     names: Sequence[Hashable] | None | lib.NoDefault = <no_default>,
#     index_col: IndexLabel | Literal[False] | None = None,
#     usecols: UsecolsArgType = None,
#     dtype: DtypeArg | None = None,
#     engine: CSVEngine | None = None,
#     converters: Mapping[HashableT, Callable] | None = None,
#     true_values: list | None = None,
#     false_values: list | None = None,
#     skipinitialspace: bool = False,
#     skiprows: list[int] | int | Callable[[Hashable], bool] | None = None,
#     skipfooter: int = 0,
#     nrows: int | None = None,
#     na_values: Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None = None,
# ...

# %%
toyata_data = pd.read_csv("data-main/car_sales/toyota_sales_data_no_header.csv",
                          delimiter=',',
                          header=None,
                          names=["sale_id","sale_rep_id","sale_date","car_model","sale_amount","commission_pct","sale_status","commission_amount"
])

# %%
toyata_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status  commission_amount
# 0   Completed                NaN
# 1     Pending                NaN
# 2   Completed                NaN
# 3   Completed                NaN
# 4   Completed                NaN

# %%
toyata_data_chunk = pd.read_csv("data-main/car_sales/toyota_sales_data_no_header.csv",
                                names=["sale_id","sale_rep_id","sale_date","car_model","sale_amount","commission_pct","sale_status","commission_amount"],
                          chunksize=100)

# %%
type(toyata_data_chunk)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
for toyata_chunk in toyata_data_chunk:
    print(toyata_chunk.head())
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status  commission_amount
# 0   Completed                NaN
# 1     Pending                NaN
# 2   Completed                NaN
# 3   Completed                NaN
# 4   Completed                NaN
#      sale_id  sale_rep_id   sale_date   car_model  sale_amount  \
# 100      101            7  2024-11-13        RAV4     32219.86
# 101      102            2  2024-11-01      Tacoma     36531.02
# 102      103            6  2024-11-04  Highlander     39423.27
# ...

# %%
toyata_data_chunk

# %%
toyata_data
# Out:
#          1  16  2024-11-18   Tundra  44496.88  0.05  Completed
# 0        2  11  2024-11-08   Tacoma  34824.72   NaN    Pending
# 1        3   5  2024-11-03  Corolla  20275.08   NaN  Completed
# 2        4  20  2024-11-06  Corolla  20068.93   NaN  Completed
# 3        5   1  2024-11-26   Tundra  49811.99  0.03  Completed
# 4        6  14  2024-11-28     RAV4  34346.20  0.03  Completed
# ...    ...  ..         ...      ...       ...   ...        ...
# 4994  4996   1  2024-11-06  Corolla  21484.83  0.05  Completed
# 4995  4997   8  2024-11-11    Camry  26519.24  0.05    Pending
# 4996  4998  18  2024-11-06   Tacoma  30780.39  0.02  Completed
# 4997  4999  10  2024-11-21  Corolla  22654.59   NaN  Completed
# 4998  5000  13  2024-11-21   Tundra  44525.85   NaN  Cancelled
#
# [4999 rows x 7 columns]

# %%
toyata_data = pd.DataFrame("data-main/car_sales/toyata_sales_data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 toyata_data = pd.DataFrame("data-main/car_sales/toyata_sales_data")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
toyata_data = pd.read_csv("data-main/car_sales/toyota_sales_data.csv")

# %%
toyata_data
# Out:
#       sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0           1           16  2024-11-18    Tundra     44496.88            0.05
# 1           2           11  2024-11-08    Tacoma     34824.72             NaN
# 2           3            5  2024-11-03   Corolla     20275.08             NaN
# 3           4           20  2024-11-06   Corolla     20068.93             NaN
# 4           5            1  2024-11-26    Tundra     49811.99            0.03
# ...       ...          ...         ...       ...          ...             ...
# 4995     4996            1  2024-11-06   Corolla     21484.83            0.05
# 4996     4997            8  2024-11-11     Camry     26519.24            0.05
# 4997     4998           18  2024-11-06    Tacoma     30780.39            0.02
# 4998     4999           10  2024-11-21   Corolla     22654.59             NaN
# 4999     5000           13  2024-11-21    Tundra     44525.85             NaN
#
#      sale_status
# ...

# %%
toyata_data['commission_amt'] = (toyata_data['sale_amount']*toyata_data['commission_pct']).fillna(0).round(2)

# %%
toyata_data.head()
# Out:
#    sale_id  sale_rep_id   sale_date car_model  sale_amount  commission_pct  \
# 0        1           16  2024-11-18    Tundra     44496.88            0.05
# 1        2           11  2024-11-08    Tacoma     34824.72             NaN
# 2        3            5  2024-11-03   Corolla     20275.08             NaN
# 3        4           20  2024-11-06   Corolla     20068.93             NaN
# 4        5            1  2024-11-26    Tundra     49811.99            0.03
#
#   sale_status  commission_amt
# 0   Completed         2224.84
# 1     Pending            0.00
# 2   Completed            0.00
# 3   Completed            0.00
# 4   Completed         1494.36

# %%
help(toyata_data.to_csv)
# Out:
# Help on method to_csv in module pandas.core.generic:
#
# to_csv(
#     path_or_buf: FilePath | WriteBuffer[bytes] | WriteBuffer[str] | None = None,
#     *,
#     sep: str = ',',
#     na_rep: str = '',
#     float_format: str | Callable | None = None,
#     columns: Sequence[Hashable] | None = None,
#     header: bool | list[str] = True,
#     index: bool = True,
#     index_label: IndexLabel | None = None,
#     mode: str = 'w',
#     encoding: str | None = None,
#     compression: CompressionOptions = 'infer',
#     quoting: int | None = None,
#     quotechar: str = '"',
#     lineterminator: str | None = None,
#     chunksize: int | None = None,
#     date_format: str | None = None,
#     doublequote: bool = True,
#     escapechar: str | None = None,
#     decimal: str = '.',
#     errors: OpenFileErrors = 'strict',
#     storage_options: StorageOptions | None = None
# ) -> str | None method of pandas.DataFrame instance
#     Write object to a comma-separated values (csv) file.
# ...

# %%
toyata_data.to_csv("data-main/car_sales/toyota_sales_data_commission.csv")
